# %%
import pandas as pd

# %%
tracks = pd.read_csv('./data/tracks.csv')

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
tracks[tracks['popularity'] >= 89]
# Out:
#                             id                              name  popularity  \
# 86016   2QjOHCTQ1Jl3zawyYOpxh6                   Sweater Weather          90
# 90900   0u2P5u6lvoDfwTYjAADbn4              lovely (with Khalid)          89
# 91866   60ynsPSSKe6O3sfwRnIBRf                           Streets          94
# 91867   6UelLqGlWMcVH1E5c4H7lY                  Watermelon Sugar          92
# 91869   7qEHsqek33rTcFNT9PFqLf                 Someone You Loved          90
# ...                        ...                               ...         ...
# 93821   43PGPuHIlVOc04jrZVh9L6                           RAPSTAR          89
# 93822   31qCy5ZaophVA81wtlwLc4                            Anyone          90
# 93823   65OVbaJR5O1RmwOQx0875b  Wants and Needs (feat. Lil Baby)          89
# 93825   2MZQAvsA7aZDssppBLRxYp         Batom de Cereja - Ao Vivo          89
# 115733  2etHQJxIbV0soyPhelVs9Y      Best Friend (feat. Doja Cat)          90
#
# ...

# %%
tableau_data = pd.concat([tracks[tracks['popularity'] >= 89]], axis=0).reset_index()

# %%
url = ['https://open.spotify.com/embed/track/2QjOHCTQ1Jl3zawyYOpxh6?utm_source=generator', # sweater weather
      'https://open.spotify.com/embed/track/0u2P5u6lvoDfwTYjAADbn4?utm_source=generator', # lovely
      'https://open.spotify.com/embed/track/60ynsPSSKe6O3sfwRnIBRf?utm_source=generator', # streets
      'https://open.spotify.com/embed/track/6UelLqGlWMcVH1E5c4H7lY?utm_source=generator', # watermelon sugar
      'https://open.spotify.com/embed/track/7qEHsqek33rTcFNT9PFqLf?utm_source=generator', # someone you loved
      'https://open.spotify.com/embed/track/21jGcNKet2qwijlDFuPiPb?utm_source=generator', # circles
      'https://open.spotify.com/embed/track/1Xi84slp6FryDSCbzq4UCD?utm_source=generator', # arcade
      'https://open.spotify.com/embed/track/5QO79kh1waicV47BqGRL3g?utm_source=generator', # save your tears
      'https://open.spotify.com/embed/track/6tDDoYIxWvMLTdKpjFkc1B?utm_source=generator', # telepatia
      'https://open.spotify.com/embed/track/0VjIjW4GlUZAMYd2vXMi3b?utm_source=generator', # blinding lights
      'https://open.spotify.com/embed/track/6f3Slt0GbA2bPZlz0aIFXN?utm_source=generator', # the business
      'https://open.spotify.com/embed/track/3FAJ6O0NOHQV8Mc5Ri6ENp?utm_source=generator', # heartbreak anniversary
      'https://open.spotify.com/embed/track/27OeeYzk6klgBh83TSvGMA?utm_source=generator', # without you
      'https://open.spotify.com/embed/track/1xK1Gg9SxG8fy2Ya373oqb?utm_source=generator', # bandito
      'https://open.spotify.com/embed/track/2XIc1pqjXV3Cr2BQUGNBck?utm_source=generator', # la noche de anoche
      'https://open.spotify.com/embed/track/3YJJjQPAbDT7mGpX3WtQ9A?utm_source=generator', # good days
      'https://open.spotify.com/embed/track/47EiUVwUp4C9fGccaPuUCS?utm_source=generator', # dakiti
      'https://open.spotify.com/embed/track/35mvY5S1H3J2QZyna3TFe0?utm_source=generator', # positions
      'https://open.spotify.com/embed/track/3VvA1wSxukMLsvXoXtlwWx?utm_source=generator', # hecha pa mi
      'https://open.spotify.com/embed/track/6ft4hAq6yde8jPZY2i5zLr?utm_source=generator', # paradise
      'https://open.spotify.com/embed/track/5QDLhrAOJJdNAmCTJ8xMyW?utm_source=generator', # dynamite
      'https://open.spotify.com/embed/track/45bE4HXI0AwGZXfZtMp8JR?utm_source=generator', # you broke me first
      'https://open.spotify.com/embed/track/7vrJn5hDSXRmdXoR30KgF1?utm_source=generator', # bichota
      'https://open.spotify.com/embed/track/6Im9k8u9iIzKMrmV7BWtlF?utm_source=generator', # 34+35
      'https://open.spotify.com/embed/track/7ytR5pFWmSjzHJIeQkgog4?utm_source=generator', # rockstar
      'https://open.spotify.com/embed/track/6cx06DFPPHchuUAcTxznu9?utm_source=generator', # head and heart
      'https://open.spotify.com/embed/track/1tkg4EHVoqnhR6iFEXb60y?utm_source=generator', # what you know bout love
      'https://open.spotify.com/embed/track/463CkQjx2Zk1yXoBuierM9?utm_source=generator', # levatating
      'https://open.spotify.com/embed/track/20R4HfKloPKgXDqU7UKk3x?utm_source=generator', # therefore i am
      'https://open.spotify.com/embed/track/47EiUVwUp4C9fGccaPuUCS?utm_source=generator', # dakiti
      'https://open.spotify.com/embed/track/4Oun2ylbjFKMPTiaSbbCih?utm_source=generator', # wap
      'https://open.spotify.com/embed/track/1KixkQVDUHggZMU9dUobgm?utm_source=generator', # my head and my heart
      'https://open.spotify.com/embed/track/4xqrdfXkTW4T0RauPLv3WA?utm_source=generator', # heather
      'https://open.spotify.com/embed/track/5vGLcdRuSbUhD8ScwsGSdA?utm_source=generator', # whoopty
      'https://open.spotify.com/embed/track/1zLBsSVxETQOfINOLYvT5m?utm_source=generator', # girls like me
      'https://open.spotify.com/embed/track/0PvFJmanyNQMseIFrU708S?utm_source=generator', # for the night
      'https://open.spotify.com/embed/track/6zFMeegAMYQo0mt8rXtrli?utm_source=generator', # holiday
      'https://open.spotify.com/embed/track/7ndTONDDRFGiPnnhOzOXxq?utm_source=generator', # la nota
      'https://open.spotify.com/embed/track/5FVbvttjEvQ8r2BgUcJgNg?utm_source=generator', # life goes on
      'https://open.spotify.com/embed/track/463CkQjx2Zk1yXoBuierM9?utm_source=generator', # levatating
      'https://open.spotify.com/embed/track/7eJMfftS33KTjuF7lTsMCx?utm_source=generator', # death bed
      'https://open.spotify.com/embed/track/6gBFPUFcJLzWGx4lenP6h2?utm_source=generator', # goosebumps
      'https://open.spotify.com/embed/track/4iJyoBOLtHqaGxP12qzhQI?utm_source=generator', # peaches
      'https://open.spotify.com/embed/track/5wANPM4fQCJwkGd4rN57mH?utm_source=generator', # drivers license
      'https://open.spotify.com/embed/track/3Ofmpyhv5UAQ70mENzB277?utm_source=generator', # astronaut in the ocean
      'https://open.spotify.com/embed/track/4pryE6cN2gFL1FVF5fYINl?utm_source=generator', # leave the door open
      'https://open.spotify.com/embed/track/56KhDgM8O8rHxBI7CIEGCw?utm_source=generator', # fiel
      'https://open.spotify.com/embed/track/4cG7HUWYHBV6R6tHn1gxrl?utm_source=generator', # friday
      'https://open.spotify.com/embed/track/5YYW3yRktprLRr47WK219Y?utm_source=generator', # ella no es tuya
      'https://open.spotify.com/embed/track/1XXimziG1uhM0eDNCZCrUl?utm_source=generator', # up
      'https://open.spotify.com/embed/track/5uEYRdEIh9Bo4fpjDd4Na9?utm_source=generator', # goosebumps remix
      'https://open.spotify.com/embed/track/1nahzW3kfMuwReTka28tH5?utm_source=generator', # hold on
      'https://open.spotify.com/embed/track/3iw6V4LH7yPj1ESORX9RIN?utm_source=generator', # wellerman
      'https://open.spotify.com/embed/track/2TksvaRivgAEj780DgRB73?utm_source=generator', # 911 
      'https://open.spotify.com/embed/track/5YaskwnGDZFDRipaqzbwQx?utm_source=generator', # your love
      'https://open.spotify.com/embed/track/3aQem4jVGdhtg116TmJnHz?utm_source=generator', # whats next
      'https://open.spotify.com/embed/track/1diS6nkxMQc3wwC4G1j0bh?utm_source=generator', # were good
      'https://open.spotify.com/embed/track/079Ey5uxL04AKPQgVQwx5h?utm_source=generator', # baila conmigo
      'https://open.spotify.com/embed/track/5zFglKYiknIxks8geR8rcL?utm_source=generator', # beautiful mistakes
      'https://open.spotify.com/embed/track/6HU7h9RYOaPRFeh0R3UeAr?utm_source=generator', # deja vu
      'https://open.spotify.com/embed/track/18vXApRmJSgQ6wG2ll9AOg?utm_source=generator', # rapstar
      'https://open.spotify.com/embed/track/2WnAKZefdRHxtBEkRjFOHC?utm_source=generator', # anyone
      'https://open.spotify.com/embed/track/65OVbaJR5O1RmwOQx0875b?utm_source=generator', # wants and needs
      'https://open.spotify.com/embed/track/2MZQAvsA7aZDssppBLRxYp?utm_source=generator', # batom de cereja
      'https://open.spotify.com/embed/track/2etHQJxIbV0soyPhelVs9Y?utm_source=generator' # best friends
      ]

# %%
tableau_data['url'] = url

# %%
from IPython.display import HTML
HTML(tableau_data.to_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>id</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>duration_ms</th>
#       <th>explicit</th>
#       <th>artists</th>
#       <th>id_artists</th>
#       <th>release_date</th>
#       <th>danceability</th>
#       <th>energy</th>
#       <th>key</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>speechiness</th>
#       <th>acousticness</th>
#       <th>instrumentalness</th>
#       <th>liveness</th>
#       <th>valence</th>
#       <th>tempo</th>
#       <th>time_signature</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>86016</td>
#       <td>2QjOHCTQ1Jl3zawyYOpxh6</td>
#       <td>Sweater Weather</td>
#       <td>90</td>
#       <td>240400</td>
#       <td>0</td>
#       <td>['The Neighbourhood']</td>
#       <td>['77SW9BnxLY8rJ0RciFqkHh']</td>
# ...

# %%
tableau_data.to_csv('./data/tableau_data.csv')
